# %%
import os
import json
import pandas as pd
import matplotlib as plt

# %%
file_to_load = 'outputs/2018_fires'
pd.set_option('mode.chained_assignment', None)
# Read Purchasing File and store into Pandas data frame
fire18_df = pd.read_csv(file_to_load)
fire18_df
# Out:
#      Unnamed: 0                           Name  Acres Burned   Latitude  \
# 0             0                  Aqueduct Fire          30.0  35.924360
# 1             1  Montecito Flooding / Mudflows           0.0   0.000000
# 2             2                   Haycamp Fire          50.0  35.966890
# 3             3                  Pleasant Fire        2070.0  37.402080
# 4             4                    Wilcox Fire          33.0   0.000000
# ..          ...                            ...           ...        ...
# 305         305                    Sierra Fire         147.0  34.180750
# 306         306                     Niles Fire          20.0  37.611580
# 307         307                    Briggs Fire         150.0  34.301667
# 308         308                      Peak Fire         186.0  34.267348
# 309         309                     Bear Fire           10.0  37.128570
#
#       Longitude Fire Started Fire Extinguished
# 0   -119.940830   2018-04-12        2019-01-03
# ...

# %%
file_to_load = 'outputs/2015_fires'
pd.set_option('mode.chained_assignment', None)
# Read Purchasing File and store into Pandas data frame
fire15_df = pd.read_csv(file_to_load)
fire15_df.head(40)
# Out:
#     Unnamed: 0                 Name         Counties Acres Burned   Latitude  \
# 0            0        Stephens Fire         Siskiyou          200  41.485000
# 1            1           Round Fire       Inyo, Mono        7,000   0.000000
# 2            2        Van Dyke Fire             Mono          509   0.000000
# 3            3            Otay Fire        San Diego           80  32.644916
# 4            4            Ward Fire           Plumas          137  40.050833
# 5            5         Highway Fire        Riverside        1,049  33.884313
# 6            6         Forebay Fire           Merced          275  37.083120
# 7            7     Christensen Fire          Alameda          242   0.000000
# 8            8        Harrison Fire        Riverside           80   0.000000
# 9            9            Site Fire          Alameda          300   0.000000
# 10          10            Snow Fire        Riverside           25   0.000000
# ...

# %%
file_to_load = 'outputs/2013_fires'
pd.set_option('mode.chained_assignment', None)
# Read Purchasing File and store into Pandas data frame
fire13_df = pd.read_csv(file_to_load)
fire13_df
# Out:
#      Unnamed: 0             Name  Acres Burned   Latitude   Longitude  \
# 0             0       Becks Fire         296.0   0.000000    0.000000
# 1             1       River Fire         406.0  36.602575 -118.016510
# 2             2      Jurupa Fire         311.0   0.000000    0.000000
# 3             3       Butte Fire          80.0   0.000000    0.000000
# 4             4    Fawnskin Fire          30.0  34.288877 -116.941311
# ..          ...              ...           ...        ...         ...
# 154         154         Dam Fire          23.0  38.928900 -122.581800
# 155         155  Happy Camp Fire          44.0   0.000000    0.000000
# 156         156    Pfeiffer Fire         917.0   0.000000    0.000000
# 157         157      Refuse Fire          15.0   0.000000    0.000000
# 158         158       Grant Fire          40.0  37.342186 -121.717706
#
#     Fire Started Fire Extinguished
# 0     2013-01-22        2013-01-23
# 1     2013-02-24        2013-02-28
# ...

# %%
fire18_df['Acres Burned'].sum()
# Out:
# 1618033.0

# %%
fire15_df['Acres Burned'].sum()
# Out:
# '2007,000509801371,049275242803002525452511036201,5426738605517131,3596012215860500920135605331,7915316404151001935211421117535515045253517023150401854952143214181251004,2501,3332006025430248,051267511677167251,4502,3041585,70211440166,98040069,438752122041121959086504,88336,50305432824,86377,0817552653029,416597,50930,36122710,5705511025,1181,8501863,6763002,4463741462,700221676921555128673723010811035454017070,8682154151,0421092976,067104151,6231,38850860583667021301,08695'

# %%
fire13_df['Acres Burned'].sum()
# Out:
# 523966.0
