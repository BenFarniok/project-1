# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import os
import json
# Import API key
#from api_keys import gkey
file_to_load = 'outputs/2015_fires'
pd.set_option('mode.chained_assignment', None)
# Read Purchasing File and store into Pandas data frame
fire_df = pd.read_csv(file_to_load)

# %%
nocoords = fire_df[fire_df['Latitude'] == 0.00000 ].index
fire_df.drop(nocoords, inplace= True)
fire_df.tail(40)
# Out:
#      Unnamed: 0                       Name         Counties Acres Burned  \
# 91           91                 Vasco Fire     Contra Costa          195
# 92           92                 Sprig Fire           Shasta           90
# 93           93               Advance Fire           Tulare           86
# 94           94  Mendocino Lightning Fires        Mendocino           50
# 98           98                  Anza Fire        Riverside          543
# 100         100                  Frog Fire            Modoc        4,863
# 102         102                  Fern Fire           Shasta           75
# 103         103                 White Fire    Santa Barbara           52
# 105         105               Francis Fire             Yuba           30
# 107         107                 Point Fire           Shasta           59
# 111         111                 Dodge Fire           Lassen       10,570
# 112         112                De Luz Fire        San Diego           55
# 113         113                    36 Fire           Tehama          110
# 114         114             Jerusalem Fire       Lake, Napa       25,118
# 119         119                Cuesta Fire  San Luis Obispo        2,446
# 121         121                 Horse Fire         Humboldt          146
# 122         122                 Tesla Fire          Alameda        2,700
# 123         123                 Grade Fire             Lake           22
# 126         126              Peterson Fire             Lake          215
# 127         127                Summit Fire   San Bernardino           55
# 128         128              Democrat Fire          Trinity          128
# 129         129                   Elk Fire             Lake          673
# 130         130                 Olive Fire            Butte           72
# 131         131               Kramer Fire            Lassen           30
# 132         132                   Oak Fire         Tuolumne          108
# 134         134                Browns Fire          Trinity           35
# 136         136                Center Fire           Lassen           40
# 137         137                 Creek Fire           Fresno          170
# 138         138                 Butte Fire              NaN       70,868
# 141         141               Lumpkin Fire            Butte        1,042
# 142         142                Walker Fire           Shasta          109
# 145         145                Munjar Fire            Butte          104
# 146         146                Rough Fire            Fresno      151,623
# 147         147               Solimar Fire              NaN        1,388
# 148         148               Potrero Fire          Ventura           50
# 152         152               Cienega Fire       San Benito          670
# 153         153             Gibraltar Fire    Santa Barbara           21
# 154         154            McCourtney Fire           Nevada           30
# 155         155             Tassajara Fire         Monterey        1,086
# 156         156              Laureles Fire         Monterey           95
#
#       Latitude   Longitude Fire Started Fire Extinguished
# 91   37.816290 -121.681130   2015-07-30        2015-07-30
# 92   40.498650 -122.201090   2015-07-30        2015-07-31
# 93   36.498450 -118.900900   2015-07-30        2015-08-05
# 94   39.433010 -123.363160   2015-07-30        2015-08-03
# 98   33.573600 -116.538700   2015-08-10        2015-08-15
# 100  41.399000 -121.392000   2015-07-30        2015-07-31
# 102  40.678680 -121.932440   2015-08-02        2015-08-04
# 103  34.952200 -120.290300   2015-08-01        1969-12-31
# 105  39.333030 -121.187350   2015-08-03        2015-08-05
# 107  40.392900 -122.405460   2015-08-03        2015-08-04
# 111  40.938000 -120.105000   2015-08-03        2015-08-04
# 112  33.411597 -117.288625   2015-08-09        2015-08-10
# 113  40.350687 -121.778680   2015-08-08        2015-08-09
# 114  38.814250 -122.486732   2015-08-09        2015-08-25
# 119  35.347700 -120.626900   2015-08-16        2015-08-28
# 121  40.105882 -124.072042   2015-08-18        2015-08-29
# 122  37.384500 -121.373200   2015-08-19        2015-08-22
# 123  38.831478 -122.534280   2015-08-24        2015-08-25
# 126  38.925764 -122.879272   2015-08-22        2015-08-27
# 127  34.230000 -116.883000   2015-08-23        2015-09-11
# 128  40.724898 -122.961740   2015-08-25        2015-08-29
# 129  55.230000 -122.000000   2015-09-02        2015-09-08
# 130  26.420000 -121.000000   2015-09-02        2015-09-03
# 131  41.123620 -121.194256   2015-08-29        2015-08-30
# 132  38.046840 -120.301880   2015-09-08        2015-09-15
# 134  40.000000   41.460000   2015-09-08        2015-09-10
# 136  40.400196 -120.553075   2015-09-09        2015-09-10
# 137  40.400196 -120.553075   2015-09-09        2015-09-11
# 138  38.329740 -120.704180   2015-09-09        2015-10-15
# 141  39.521800 -121.336300   2015-09-11        2015-09-17
# 142  40.475120 -122.525410   2015-09-11        2015-09-13
# 145  39.870700 -121.893800   2015-10-02        2015-10-02
# 146  36.874000 -118.905000   2015-07-31        2015-11-09
# 147  34.319530 -119.345120   2015-12-25        2015-12-29
# 148  34.150000 -118.879444   2015-11-07        2015-11-07
# 152  36.708540 -121.327340   2015-10-12        2015-10-16
# 153  34.482800 -119.632160   2015-10-29        2015-11-09
# 154  39.081000 -121.194000   2015-09-22        2015-09-21
# 155  36.369964 -121.589554   2015-09-19        2015-09-27
# 156  36.569637 -121.755603   2015-09-19        2015-09-21

# %%
datelist=[]
temp = []
windspeed= []
precip = []
humidity = []
visi = []
pressure = []
cloudcover = []
windgust = []
uvindex = []
location = ''
date = ''

# %%
base_url = "http://api.worldweatheronline.com/premium/v1/past-weather.ashx"
api_key='YOUR API KEY HERE'
#location = '35.924360,-119.940830'

call = f'http://api.worldweatheronline.com/premium/v1/past-weather.ashx?key={api_key}&q={location}&format=json&date={date}&endate={date}&tp=24'


for index, row in fire_df.iterrows():
    lat = row["Latitude"]
    lng = row["Longitude"]
    location = f"{lat},{lng}"
    date = row['Fire Started']
    call = f'http://api.worldweatheronline.com/premium/v1/past-weather.ashx?key={api_key}&q={location}&format=json&date={date}&endate={date}&tp=24'
    response = requests.get(call).json()
    try: 
        datelist.append((response['data']['weather'][0]['date']))
        temp.append(response['data']['weather'][0]['maxtempF'])
        windspeed.append(response['data']['weather'][0]['hourly'][0]['windspeedMiles'])
        precip.append(response['data']['weather'][0]['hourly'][0]['precipMM'])
        humidity.append(response['data']['weather'][0]['hourly'][0]['humidity'])
        visi.append(response['data']['weather'][0]['hourly'][0]['visibilityMiles'])
        pressure.append(response['data']['weather'][0]['hourly'][0]['pressureInches'])
        cloudcover.append(response['data']['weather'][0]['hourly'][0]['cloudcover'])
        windgust.append(response['data']['weather'][0]['hourly'][0]['WindGustMiles'])
        uvindex.append(response['data']['weather'][0]['hourly'][0]['uvIndex'])
 #   hotel_df.loc[index, "Hotel Name"] = response["results"][0]["name"]
    except:
        print(f"couldn't find information for {index}" )
#print(response)    
  #  hist_weather_data_2010 = retrieve_hist_data(api_key,
                               # location,
                               # date,
                               # end_date,
                               # frequency,
                               # location_label = False,
                               # export_csv = True,
                               # store_df = True)
# Out:
# couldn't find information for 130

# %%
data_df = pd.DataFrame({'Location': location,
            'Precipitation(MM)':precip, 
           'Humidity':humidity,
           'Temperature':temp, 
           'Humidity': humidity,
           'Wind Speed': windspeed,
            'Wind Gust': windgust,
            'Temperature':temp,
           'Cloud Cover':cloudcover,
            'Date':datelist})
data_df
# Out:
#                           Location Precipitation(MM) Humidity Temperature  \
# 0   36.5696373,-121.75560290000001               0.0       34          59
# 1   36.5696373,-121.75560290000001               0.1       62          78
# 2   36.5696373,-121.75560290000001               1.8       72          48
# 3   36.5696373,-121.75560290000001               0.0       38          82
# 4   36.5696373,-121.75560290000001               0.0       45          76
# ..                             ...               ...      ...         ...
# 93  36.5696373,-121.75560290000001               0.0       53          92
# 94  36.5696373,-121.75560290000001               0.0       52          71
# 95  36.5696373,-121.75560290000001               0.0       26          84
# 96  36.5696373,-121.75560290000001               0.0       59          81
# 97  36.5696373,-121.75560290000001               0.0       73          71
#
#    Wind Speed Wind Gust Cloud Cover        Date
# 0           4         8          15  2015-02-24
# 1           5         6          35  2015-06-26
# 2           7        11          54  2015-04-13
# 3           4         6           0  2015-04-18
# 4           9        14          29  2015-05-11
# ..        ...       ...         ...         ...
# 93          2         3           0  2015-10-12
# 94         10        17           0  2015-10-29
# 95          7        12           0  2015-09-22
# 96          4         7           7  2015-09-19
# 97          6         9          45  2015-09-19
#
# [98 rows x 8 columns]

# %%
data_df.to_csv("outputs/fireweather2015.csv" , index = True)

# %%
print(response['data']['weather'])
# Out:
# [{'date': '2015-09-19', 'astronomy': [{'sunrise': '06:52 AM', 'sunset': '07:09 PM', 'moonrise': '12:35 PM', 'moonset': '11:09 PM', 'moon_phase': 'Waxing Crescent', 'moon_illumination': '39'}], 'maxtempC': '22', 'maxtempF': '71', 'mintempC': '12', 'mintempF': '53', 'avgtempC': '16', 'avgtempF': '61', 'totalSnow_cm': '0.0', 'sunHour': '8.9', 'uvIndex': '4', 'hourly': [{'time': '24', 'tempC': '22', 'tempF': '71', 'windspeedMiles': '6', 'windspeedKmph': '9', 'winddirDegree': '269', 'winddir16Point': 'W', 'weatherCode': '176', 'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0009_light_rain_showers.png'}], 'weatherDesc': [{'value': 'Patchy rain possible'}], 'precipMM': '0.0', 'precipInches': '0.0', 'humidity': '73', 'visibility': '9', 'visibilityMiles': '5', 'pressure': '1014', 'pressureInches': '30', 'cloudcover': '45', 'HeatIndexC': '18', 'HeatIndexF': '64', 'DewPointC': '12', 'DewPointF': '54', 'WindChillC': '17', 'WindChillF': '63', 'WindGustMiles': '9', 'WindGustKmph': '14', 'FeelsLikeC': '17', 'FeelsLikeF': '63', 'uvIndex': '4'}]}]
