# %%
import wwo_hist as hisapi
apiKey = ''
hist = hisapi.retrieve_hist_data(apiKey, ['Minneapolis'], '01-JAN-2010', '01-JAN-2014', 24, True, False, False)
print(hist)
# Out:
# Retrieving weather data for Minneapolis
#
#
# Currently retrieving data for Minneapolis: from 2010-01-01 to 2010-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.056335
# Currently retrieving data for Minneapolis: from 2010-02-01 to 2010-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:01.859757
# Currently retrieving data for Minneapolis: from 2010-03-01 to 2010-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.766758
# Currently retrieving data for Minneapolis: from 2010-04-01 to 2010-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:03.687565
# Currently retrieving data for Minneapolis: from 2010-05-01 to 2010-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.703615
# Currently retrieving data for Minneapolis: from 2010-06-01 to 2010-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:05.709733
# Currently retrieving data for Minneapolis: from 2010-07-01 to 2010-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:06.772263
# Currently retrieving data for Minneapolis: from 2010-08-01 to 2010-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:07.730968
# ...
