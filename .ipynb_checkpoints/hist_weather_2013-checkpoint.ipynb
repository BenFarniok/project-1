# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import os
import json
# Import API key
#from api_keys import gkey
file_to_load = 'outputs/2013_fires'
pd.set_option('mode.chained_assignment', None)
# Read Purchasing File and store into Pandas data frame
fire_df = pd.read_csv(file_to_load)

# %%
nocoords = fire_df[fire_df['Latitude'] == 0.00000 ].index
fire_df.drop(nocoords, inplace= True)
firehead= fire_df.tail(40)
firehead
# Out:
#      Unnamed: 0                                   Name  Acres Burned  \
# 113         113                            Clover Fire        8073.0
# 114         114       Plumas Lightning Complex (Hough)         513.0
# 115         115                           Shirley Fire         794.0
# 116         116  Burney Lightning Series (Warner Fire)         196.0
# 117         117                            Sierra Fire         200.0
# 118         118                              Deer Fire       11429.0
# 119         119                          Gobblers Fire         413.0
# 120         120                              Fish Fire        2060.0
# 121         121                            Empire Fire          38.0
# 122         122                            Little Fire          97.0
# 123         123                          Chestnut Fire          41.0
# 124         124                            Morgan Fire        3111.0
# 125         125                            Angora Fire         134.0
# 126         126                           Liveoak Fire          73.0
# 127         127                             Madre Fire         268.0
# 128         128                    Davis Creek Complex          97.0
# 129         129                             Tyler Fire          52.0
# 130         130                       Centerville Fire          80.0
# 131         131                              Rail Fire          68.0
# 132         132                               Rim Fire      257314.0
# 133         133                              Lyon Fire         263.0
# 135         135                         Lakeshore Fire          30.0
# 136         136                             Creek Fire          94.0
# 138         138                          Highland Fire          98.0
# 139         139                             Putah Fire         376.0
# 141         141                             Crane Fire         159.0
# 142         142                             DeLuz Fire        2236.0
# 143         143                            Summit Fire         305.0
# 144         144                             Baker Fire          40.0
# 145         145                             Capay Fire         163.0
# 146         146                            Dersch Fire          33.0
# 147         147                              Toro Fire          51.0
# 148         148                          Cantwell Fire         120.0
# 149         149                         Silverado Fire         190.0
# 150         150                           Wheeler Fire          64.0
# 151         151                             Retek Fire          82.0
# 152         152                            McCabe Fire        3505.0
# 153         153                            Bruner Fire          50.0
# 154         154                               Dam Fire          23.0
# 158         158                             Grant Fire          40.0
#
#       Latitude   Longitude Fire Started Fire Extinguished
# 113  40.498332 -122.535496   2013-09-09        2013-09-15
# 114  40.008420 -120.764666   2013-08-18        2013-08-25
# 115  35.707000 -118.588000   2013-08-18        2013-08-24
# 116  40.544500 -121.375400   2013-08-19        2013-08-23
# 117  34.200000 -117.417000   2013-09-24        2013-09-30
# 118  40.042630 -121.853970   2013-08-23        2013-08-29
# 119  34.302000 -117.598000   2013-08-20        2013-08-20
# 120  36.208000 -118.444000   2013-08-24        2013-09-24
# 121  38.895550 -120.847160   2013-08-24        2013-08-24
# 122  33.642000 -116.706000   2013-08-24        2013-08-30
# 123  37.667295 -122.427285   2013-09-07        2013-09-07
# 124  37.907570 -121.882582   2013-09-08        2013-09-14
# 125  36.258000 -118.459000   2013-09-08        2013-09-24
# 126  34.003151 -117.106075   2013-09-11        2013-09-12
# 127  34.149000 -117.908000   2013-09-23        2013-09-28
# 128  41.733250 -120.375000   2013-09-05        2013-09-24
# 129  39.333401 -121.107022   2013-08-31        2013-08-31
# 130  39.731878 -121.713938   2013-08-31        2013-09-01
# 131  41.569000 -120.959000   2013-09-07        2013-09-05
# 132  37.857000 -120.086000   2013-08-17        2013-09-06
# 133  32.710918 -116.746023   2013-09-09        2013-09-12
# 135  38.977700 -122.683000   2013-09-15        2013-09-15
# 136  35.439300 -120.835800   2013-09-24        2013-09-24
# 138  38.925200 -122.966000   2013-09-28        2013-09-29
# 139  38.628000 -122.289000   2013-10-03        2013-10-04
# 141  38.345990 -122.650300   2013-10-04        2013-10-05
# 142  33.341000 -117.309200   2013-10-05        2013-10-09
# 143  39.439000 -121.497000   2013-10-04        2013-10-05
# 144  33.765500 -117.664900   2013-10-06        2013-10-09
# 145  38.674790 -122.087250   2013-11-04        2013-11-04
# 146  40.483662 -122.140914   2013-11-07        2013-11-07
# 147  35.457978 -120.751555   2013-11-08        2013-11-09
# 148  38.882214 -122.567525   2013-11-08        2013-11-10
# 149  38.382000 -122.311000   2013-11-21        2013-11-23
# 150  34.384000 -119.132490   2013-11-14        2013-11-15
# 151  39.044200 -123.147800   2013-11-22        2013-11-22
# 152  38.816700 -122.849800   2013-11-22        2013-11-27
# 153  39.044800 -122.765600   2013-11-23        2013-11-24
# 154  38.928900 -122.581800   2013-11-23        2013-11-24
# 158  37.342186 -121.717706   2013-12-31        2013-12-31

# %%
datelist=[]
temp = []
windspeed= []
precip = []
humidity = []
visi = []
pressure = []
cloudcover = []
windgust = []
uvindex = []
location = ''
date = ''

# %%
base_url = "http://api.worldweatheronline.com/premium/v1/past-weather.ashx"
api_key='YOUR API KEY HERE'
#location = '35.924360,-119.940830'

call = f'http://api.worldweatheronline.com/premium/v1/past-weather.ashx?key={api_key}&q={location}&format=json&date={date}&endate={date}&tp=24'


for index, row in fire_df.iterrows():
    lat = row["Latitude"]
    lng = row["Longitude"]
    location = f"{lat},{lng}"
    date = row['Fire Started']
    call = f'http://api.worldweatheronline.com/premium/v1/past-weather.ashx?key={api_key}&q={location}&format=json&date={date}&endate={date}&tp=24'
    response = requests.get(call).json()
    try: 
        datelist.append((response['data']['weather'][0]['date']))
        temp.append(response['data']['weather'][0]['maxtempF'])
        windspeed.append(response['data']['weather'][0]['hourly'][0]['windspeedMiles'])
        precip.append(response['data']['weather'][0]['hourly'][0]['precipMM'])
        humidity.append(response['data']['weather'][0]['hourly'][0]['humidity'])
        visi.append(response['data']['weather'][0]['hourly'][0]['visibilityMiles'])
        pressure.append(response['data']['weather'][0]['hourly'][0]['pressureInches'])
        cloudcover.append(response['data']['weather'][0]['hourly'][0]['cloudcover'])
        windgust.append(response['data']['weather'][0]['hourly'][0]['WindGustMiles'])
        uvindex.append(response['data']['weather'][0]['hourly'][0]['uvIndex'])
 #   hotel_df.loc[index, "Hotel Name"] = response["results"][0]["name"]
    except:
        print(f"couldn't find information for {index}" )
#print(response)    
  #  hist_weather_data_2010 = retrieve_hist_data(api_key,
                               # location,
                               # date,
                               # end_date,
                               # frequency,
                               # location_label = False,
                               # export_csv = True,
                               # store_df = True)

# %%
data_df = pd.DataFrame({'Location': location,
            'Precipitation(MM)':precip, 
           'Humidity':humidity,
           'Temperature':temp, 
           'Humidity': humidity,
           'Wind Speed': windspeed,
            'Wind Gust': windgust,
            'Temperature':temp,
           'Cloud Cover':cloudcover,
            'Date':datelist})
data_df
# Out:
#                   Location Precipitation(MM) Humidity Temperature Wind Speed  \
# 0    37.342186,-121.717706               0.0       25          41         10
# 1    37.342186,-121.717706               0.0       23          76          5
# 2    37.342186,-121.717706               0.0       33          78          5
# 3    37.342186,-121.717706               0.0       25          59         12
# 4    37.342186,-121.717706               0.0       31          83          9
# ..                     ...               ...      ...         ...        ...
# 136  37.342186,-121.717706               0.0       23          65         10
# 137  37.342186,-121.717706               0.0       18          66         12
# 138  37.342186,-121.717706               0.0       27          64          7
# 139  37.342186,-121.717706               0.0       25          64          8
# 140  37.342186,-121.717706               0.0       58          59          2
#
#     Wind Gust Cloud Cover        Date
# 0          16           1  2013-02-24
# 1           8           0  2013-04-20
# 2           7           2  2013-04-30
# 3          19           1  2013-05-01
# 4          15           3  2013-04-30
# ..        ...         ...         ...
# 136        19           0  2013-11-22
# 137        21           0  2013-11-22
# 138        12           0  2013-11-23
# 139        14           0  2013-11-23
# 140         4          17  2013-12-31
#
# [141 rows x 8 columns]

# %%
data_df.to_csv("outputs/fireweather2013.csv" , index = True)

# %%
print(response['data']['weather'])
# Out:
# [{'date': '2013-12-31', 'astronomy': [{'sunrise': '08:21 AM', 'sunset': '05:59 PM', 'moonrise': '07:20 AM', 'moonset': '05:41 PM', 'moon_phase': 'Waning Crescent', 'moon_illumination': '1'}], 'maxtempC': '15', 'maxtempF': '59', 'mintempC': '4', 'mintempF': '39', 'avgtempC': '8', 'avgtempF': '46', 'totalSnow_cm': '0.0', 'sunHour': '8.7', 'uvIndex': '3', 'hourly': [{'time': '24', 'tempC': '15', 'tempF': '59', 'windspeedMiles': '2', 'windspeedKmph': '4', 'winddirDegree': '179', 'winddir16Point': 'S', 'weatherCode': '116', 'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}], 'weatherDesc': [{'value': 'Partly cloudy'}], 'precipMM': '0.0', 'precipInches': '0.0', 'humidity': '58', 'visibility': '10', 'visibilityMiles': '6', 'pressure': '1023', 'pressureInches': '31', 'cloudcover': '17', 'HeatIndexC': '9', 'HeatIndexF': '48', 'DewPointC': '0', 'DewPointF': '32', 'WindChillC': '9', 'WindChillF': '48', 'WindGustMiles': '4', 'WindGustKmph': '6', 'FeelsLikeC': '9', 'FeelsLikeF': '48', 'uvIndex': '3'}]}]
